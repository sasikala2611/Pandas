# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('employee_promotion.csv')

# %%
df.head(5)
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                  8           0                49.0            0
# ...

# %%
df.tail(3)
# Out:
#        employee_id         department     region   education gender  \
# 54805        13918          Analytics   region_1  Bachelor's      m
# 54806        13614  Sales & Marketing   region_9         NaN      m
# 54807        51526                 HR  region_22  Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  awards_won  avg_training_score  is_promoted
# 54805                  3           0                79.0            0
# 54806                  2           0                 NaN            0
# 54807                  5           0                49.0            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  awards_won            54808 non-null  int64
#  11  avg_training_score    52248 non-null  float64
#  12  is_promoted           54808 non-null  int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 5.4+ MB

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service    awards_won  avg_training_score   is_promoted
# count       54808.000000  54808.000000        52248.000000  54808.000000
# mean            5.865512      0.023172           63.712238      0.085170
# std             4.265094      0.150450           13.521910      0.279137
# ...

# %%
df.shape
# Out:
# (54808, 13)

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'awards_won', 'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
df['employee_id']
# Out:
# 0        65438
# 1        65141
# 2         7513
# 3         2542
# 4        48945
#          ...
# 54803     3030
# 54804    74592
# 54805    13918
# 54806    13614
# 54807    51526
# Name: employee_id, Length: 54808, dtype: int64

# %%
df[['department','region']]
# Out:
#               department     region
# 0      Sales & Marketing   region_7
# 1             Operations  region_22
# 2      Sales & Marketing  region_19
# 3      Sales & Marketing  region_23
# 4             Technology  region_26
# ...                  ...        ...
# 54803         Technology  region_14
# 54804         Operations  region_27
# 54805          Analytics   region_1
# 54806  Sales & Marketing   region_9
# 54807                 HR  region_22
#
# [54808 rows x 2 columns]

# %%
df.iloc[5]
# Out:
# employee_id                  58896
# department               Analytics
# region                    region_2
# education               Bachelor's
# gender                           m
# recruitment_channel       sourcing
# no_of_trainings                  2
# age                             31
# previous_year_rating           3.0
# length_of_service                7
# awards_won                       0
# avg_training_score            85.0
# is_promoted                      0
# Name: 5, dtype: object

# %%
df[df['age']>25]
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# awards_won                 0
# avg_training_score      2560
# is_promoted                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.dropna()
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.drop_duplicates()
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.rename(columns={'awards_won':'Awards_Won'},inplace=True)

# %%
df.drop_duplicates()
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.fillna(0)
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.sort_values('age',ascending=True)
# Out:
#        employee_id         department     region         education gender  \
# 1749         52474  Sales & Marketing  region_21        Bachelor's      m
# 53805        72627  Sales & Marketing   region_2        Bachelor's      m
# 9453         26257  Sales & Marketing  region_15        Bachelor's      m
# 7196         52162  Sales & Marketing   region_2        Bachelor's      m
# 53161        47947  Sales & Marketing   region_2  Master's & above      m
# ...            ...                ...        ...               ...    ...
# 26074        64857                 HR   region_2  Master's & above      f
# 18893        30311  Sales & Marketing   region_2        Bachelor's      m
# 46770        42536          Analytics   region_2  Master's & above      m
# 19981        73390         Operations   region_2        Bachelor's      f
# 16339        17904         Operations   region_2        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df[df['employee_id']==30311]
# Out:
#        employee_id         department    region   education gender  \
# 18893        30311  Sales & Marketing  region_2  Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 18893            sourcing                1   60                   5.0
#
#        length_of_service  Awards  avg_training_score  is_promoted
# 18893                  6       0                50.0            0

# %%
df.groupby('previous_year_rating').sum()
# Out:
#                       employee_id  \
# previous_year_rating
# 1.0                     219494882
# 2.0                     151327193
# 3.0                     668923259
# 4.0                     356191206
# 5.0                     421765427
#
#                                                              department  \
# previous_year_rating
# 1.0                   Sales & MarketingOperationsSales & MarketingHR...
# 2.0                   Sales & MarketingAnalyticsOperationsHRAnalytic...
# 3.0                   Sales & MarketingTechnologyAnalyticsOperations...
# 4.0                   AnalyticsTechnologyOperationsTechnologyOperati...
# 5.0                   Sales & MarketingOperationsSales & MarketingSa...
#
#                                                                  region  \
# previous_year_rating
# 1.0                   region_23region_7region_31region_22region_2reg...
# 2.0                   region_22region_31region_4region_20region_22re...
# ...

# %%
a=df["age"]

# %%
a
# Out:
# 0        35
# 1        30
# 2        34
# 3        39
# 4        45
#          ..
# 54802    31
# 54803    48
# 54804    37
# 54805    27
# 54807    27
# Name: age, Length: 46380, dtype: int64

# %%
b=df["department"]

# %%
b
# Out:
# 0        Sales & Marketing
# 1               Operations
# 2        Sales & Marketing
# 3        Sales & Marketing
# 4               Technology
#                ...
# 54802    Sales & Marketing
# 54803           Technology
# 54804           Operations
# 54805            Analytics
# 54807                   HR
# Name: department, Length: 46380, dtype: object

# %%
pd.merge(a,b, on='name',how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7564\2602880275.py in ?()
# ----> 1 pd.merge(a,b, on='name',how='inner')
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
# ...

# %%
pd.concat([a,b])
# Out:
# 0                       35
# 1                       30
# 2                       34
# 3                       39
# 4                       45
#                ...
# 54802    Sales & Marketing
# 54803           Technology
# 54804           Operations
# 54805            Analytics
# 54807                   HR
# Length: 92760, dtype: object

# %%
op=df.to_csv('output.csv',index=False)

# %%
 df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# Awards                  0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
df.to_csv('output.csv',index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
 
np.random.seed(32)
x = np.random.rand(40)
y = np.random.rand(40)
 
plt.plot(x, y, marker='1', linestyle='', markersize=8, color='b', label='Scatter Plot')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
 
plt.legend()
 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)
plt.plot(x,y,marker = 'o',color='b')
plt.grid(axis='x')
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.plot(x,y,marker = '*')
plt.grid()
plt.show()

# %%
## seaborn
